# %%
import pandas as pd
df = pd.read_csv("locations.csv")
df
# Out:
#        MB2023_V1_00  LANDWATER LANDWATER_NAME  LAND_AREA_SQ_KM  AREA_SQ_KM  \
# 0               100         12       Mainland       157.497825  157.497825
# 1               200         12       Mainland       120.503770  120.503770
# 2               300         12       Mainland         7.481859    7.481859
# 3               400         12       Mainland        83.342952   83.342952
# 4              1201         12       Mainland        51.238250   51.238250
# ...             ...        ...            ...              ...         ...
# 56783       4019154         12       Mainland         0.036001    0.036001
# 56784       4019155         12       Mainland         0.019734    0.019734
# 56785       4019156         12       Mainland         0.097215    0.097215
# 56786       4019157         12       Mainland         0.066195    0.066195
# 56787       4010332         12       Mainland        39.690290   39.690290
#
#         Shape_Length                retrieved_at  n_POIs  \
# ...

# %%
df.n_POIs.value_counts(dropna=False)
# Out:
# 0     44553
# 1      5505
# 2      2250
# 3      1123
# 4       649
# 5       413
# 6       314
# 25      300
# 7       244
# 8       186
# 9       155
# 11      143
# 10      139
# 12      111
# 13       96
# 14       85
# 15       84
# 16       70
# 19       67
# 18       60
# 17       59
# 20       51
# 23       41
# 22       35
# 21       33
# 24       22
# Name: n_POIs, dtype: int64
